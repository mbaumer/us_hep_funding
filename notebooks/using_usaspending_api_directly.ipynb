# %%
import pandas as pd
from datetime import datetime, timedelta
import time
import requests
import numpy as np
import json
import urllib
from pandas.io.json import json_normalize
import re
import os.path
import zipfile
from glob import glob

# %%
url ="https://api.usaspending.gov/api/v1/awards/?limit=100"
r = requests.get(url, verify=False)
r.raise_for_status()
type(r)
data = r.json() 
meta = data['page_metadata']
data = data['results']
df_API_data = pd.io.json.json_normalize(data)
# Out:
# /Users/mbaumer/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
df_API_data.col
# Out:
#     awarding_agency.id awarding_agency.office_agency  \
# 0                  153                          None
# 1                  153                          None
# 2                  153                          None
# 3                  153                          None
# 4                  153                          None
# 5                  153                          None
# 6                  153                          None
# 7                  153                          None
# 8                  153                          None
# 9                  153                          None
# 10                 153                          None
# 11                 153                          None
# 12                 153                          None
# 13                 153                          None
# 14                 153                          None
# 15                 153                          None
# 16                 153                          None
# 17                 153                          None
# 18                 153                          None
# 19                 153                          None
# 20                 153                          None
# 21                 153                          None
# 22                 153                          None
# 23                 153                          None
# 24                 153                          None
# 25                 153                          None
# 26                 153                          None
# 27                 153                          None
# 28                 153                          None
# 29                 153                          None
# ..                 ...                           ...
# 70                 153                          None
# 71                 153                          None
# 72                 153                          None
# 73                 153                          None
# 74                 153                          None
# 75                 153                          None
# 76                 153                          None
# 77                 153                          None
# 78                 153                          None
# 79                 153                          None
# 80                 153                          None
# 81                 153                          None
# 82                 153                          None
# 83                 153                          None
# 84                 153                          None
# 85                 153                          None
# 86                 153                          None
# 87                 153                          None
# 88                 153                          None
# 89                 153                          None
# 90                 153                          None
# 91                 153                          None
# 92                 153                          None
# 93                 153                          None
# 94                 153                          None
# 95                 153                          None
# 96                 153                          None
# 97                 153                          None
# 98                 153                          None
# 99                 153                          None
#
#    awarding_agency.subtier_agency.abbreviation  \
# 0                                          FSA
# 1                                          FSA
# 2                                          FSA
# 3                                          FSA
# 4                                          FSA
# 5                                          FSA
# 6                                          FSA
# 7                                          FSA
# 8                                          FSA
# 9                                          FSA
# 10                                         FSA
# 11                                         FSA
# 12                                         FSA
# 13                                         FSA
# 14                                         FSA
# 15                                         FSA
# 16                                         FSA
# 17                                         FSA
# 18                                         FSA
# 19                                         FSA
# 20                                         FSA
# 21                                         FSA
# 22                                         FSA
# 23                                         FSA
# 24                                         FSA
# 25                                         FSA
# 26                                         FSA
# 27                                         FSA
# 28                                         FSA
# 29                                         FSA
# ..                                         ...
# 70                                         FSA
# 71                                         FSA
# 72                                         FSA
# 73                                         FSA
# 74                                         FSA
# 75                                         FSA
# 76                                         FSA
# 77                                         FSA
# 78                                         FSA
# 79                                         FSA
# 80                                         FSA
# 81                                         FSA
# 82                                         FSA
# 83                                         FSA
# 84                                         FSA
# 85                                         FSA
# 86                                         FSA
# 87                                         FSA
# 88                                         FSA
# 89                                         FSA
# 90                                         FSA
# 91                                         FSA
# 92                                         FSA
# 93                                         FSA
# 94                                         FSA
# 95                                         FSA
# 96                                         FSA
# 97                                         FSA
# 98                                         FSA
# 99                                         FSA
#
#    awarding_agency.toptier_agency.abbreviation  \
# 0                                         USDA
# 1                                         USDA
# 2                                         USDA
# 3                                         USDA
# 4                                         USDA
# 5                                         USDA
# 6                                         USDA
# 7                                         USDA
# 8                                         USDA
# 9                                         USDA
# 10                                        USDA
# 11                                        USDA
# 12                                        USDA
# 13                                        USDA
# 14                                        USDA
# 15                                        USDA
# 16                                        USDA
# 17                                        USDA
# 18                                        USDA
# 19                                        USDA
# 20                                        USDA
# 21                                        USDA
# 22                                        USDA
# 23                                        USDA
# 24                                        USDA
# 25                                        USDA
# 26                                        USDA
# 27                                        USDA
# 28                                        USDA
# 29                                        USDA
# ..                                         ...
# 70                                        USDA
# 71                                        USDA
# 72                                        USDA
# 73                                        USDA
# 74                                        USDA
# 75                                        USDA
# 76                                        USDA
# 77                                        USDA
# 78                                        USDA
# 79                                        USDA
# 80                                        USDA
# 81                                        USDA
# 82                                        USDA
# 83                                        USDA
# 84                                        USDA
# 85                                        USDA
# 86                                        USDA
# 87                                        USDA
# 88                                        USDA
# 89                                        USDA
# 90                                        USDA
# 91                                        USDA
# 92                                        USDA
# 93                                        USDA
# 94                                        USDA
# 95                                        USDA
# 96                                        USDA
# 97                                        USDA
# 98                                        USDA
# 99                                        USDA
#
#    awarding_agency.toptier_agency.cgac_code  \
# 0                                       012
# 1                                       012
# 2                                       012
# 3                                       012
# 4                                       012
# 5                                       012
# 6                                       012
# 7                                       012
# 8                                       012
# 9                                       012
# 10                                      012
# 11                                      012
# 12                                      012
# 13                                      012
# 14                                      012
# 15                                      012
# 16                                      012
# 17                                      012
# 18                                      012
# 19                                      012
# 20                                      012
# 21                                      012
# 22                                      012
# 23                                      012
# 24                                      012
# 25                                      012
# 26                                      012
# 27                                      012
# 28                                      012
# 29                                      012
# ..                                      ...
# 70                                      012
# 71                                      012
# 72                                      012
# 73                                      012
# 74                                      012
# 75                                      012
# 76                                      012
# 77                                      012
# 78                                      012
# 79                                      012
# 80                                      012
# 81                                      012
# 82                                      012
# 83                                      012
# 84                                      012
# 85                                      012
# 86                                      012
# 87                                      012
# 88                                      012
# 89                                      012
# 90                                      012
# 91                                      012
# 92                                      012
# 93                                      012
# 94                                      012
# 95                                      012
# 96                                      012
# 97                                      012
# 98                                      012
# 99                                      012
#
#    awarding_agency.toptier_agency.fpds_code  \
# 0                                      1200
# 1                                      1200
# 2                                      1200
# 3                                      1200
# 4                                      1200
# 5                                      1200
# 6                                      1200
# 7                                      1200
# 8                                      1200
# 9                                      1200
# 10                                     1200
# 11                                     1200
# 12                                     1200
# 13                                     1200
# 14                                     1200
# 15                                     1200
# 16                                     1200
# 17                                     1200
# 18                                     1200
# 19                                     1200
# 20                                     1200
# 21                                     1200
# 22                                     1200
# 23                                     1200
# 24                                     1200
# 25                                     1200
# 26                                     1200
# 27                                     1200
# 28                                     1200
# 29                                     1200
# ..                                      ...
# 70                                     1200
# 71                                     1200
# 72                                     1200
# 73                                     1200
# 74                                     1200
# 75                                     1200
# 76                                     1200
# 77                                     1200
# 78                                     1200
# 79                                     1200
# 80                                     1200
# 81                                     1200
# 82                                     1200
# 83                                     1200
# 84                                     1200
# 85                                     1200
# 86                                     1200
# 87                                     1200
# 88                                     1200
# 89                                     1200
# 90                                     1200
# 91                                     1200
# 92                                     1200
# 93                                     1200
# 94                                     1200
# 95                                     1200
# 96                                     1200
# 97                                     1200
# 98                                     1200
# 99                                     1200
#
#    awarding_agency.toptier_agency.name  awarding_agency.toptier_flag  ...   \
# 0            Department of Agriculture                         False  ...
# 1            Department of Agriculture                         False  ...
# 2            Department of Agriculture                         False  ...
# 3            Department of Agriculture                         False  ...
# 4            Department of Agriculture                         False  ...
# 5            Department of Agriculture                         False  ...
# 6            Department of Agriculture                         False  ...
# 7            Department of Agriculture                         False  ...
# 8            Department of Agriculture                         False  ...
# 9            Department of Agriculture                         False  ...
# 10           Department of Agriculture                         False  ...
# 11           Department of Agriculture                         False  ...
# 12           Department of Agriculture                         False  ...
# 13           Department of Agriculture                         False  ...
# 14           Department of Agriculture                         False  ...
# 15           Department of Agriculture                         False  ...
# 16           Department of Agriculture                         False  ...
# 17           Department of Agriculture                         False  ...
# 18           Department of Agriculture                         False  ...
# 19           Department of Agriculture                         False  ...
# 20           Department of Agriculture                         False  ...
# 21           Department of Agriculture                         False  ...
# 22           Department of Agriculture                         False  ...
# 23           Department of Agriculture                         False  ...
# 24           Department of Agriculture                         False  ...
# 25           Department of Agriculture                         False  ...
# 26           Department of Agriculture                         False  ...
# 27           Department of Agriculture                         False  ...
# 28           Department of Agriculture                         False  ...
# 29           Department of Agriculture                         False  ...
# ..                                 ...                           ...  ...
# 70           Department of Agriculture                         False  ...
# 71           Department of Agriculture                         False  ...
# 72           Department of Agriculture                         False  ...
# 73           Department of Agriculture                         False  ...
# 74           Department of Agriculture                         False  ...
# 75           Department of Agriculture                         False  ...
# 76           Department of Agriculture                         False  ...
# 77           Department of Agriculture                         False  ...
# 78           Department of Agriculture                         False  ...
# 79           Department of Agriculture                         False  ...
# 80           Department of Agriculture                         False  ...
# 81           Department of Agriculture                         False  ...
# 82           Department of Agriculture                         False  ...
# 83           Department of Agriculture                         False  ...
# 84           Department of Agriculture                         False  ...
# 85           Department of Agriculture                         False  ...
# 86           Department of Agriculture                         False  ...
# 87           Department of Agriculture                         False  ...
# 88           Department of Agriculture                         False  ...
# 89           Department of Agriculture                         False  ...
# 90           Department of Agriculture                         False  ...
# 91           Department of Agriculture                         False  ...
# 92           Department of Agriculture                         False  ...
# 93           Department of Agriculture                         False  ...
# 94           Department of Agriculture                         False  ...
# 95           Department of Agriculture                         False  ...
# 96           Department of Agriculture                         False  ...
# 97           Department of Agriculture                         False  ...
# 98           Department of Agriculture                         False  ...
# 99           Department of Agriculture                         False  ...
#
#    recipient.small_business_description subaward_count total_loan_value  \
# 0                                  None              0             None
# 1                                  None              0             None
# 2                                  None              0             None
# 3                                  None              0             None
# 4                                  None              0             None
06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 1     06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 2     06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 3     06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 4     06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 5     06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 6     06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 7     06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 8     06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 9     06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 10    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 11    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 12    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 13    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 14    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 15    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 16    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 17    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 18    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 19    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 20    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 21    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 22    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 23    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 24    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 25    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 26    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 27    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 28    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 29    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# ..   ...                                                ...   ...
# 70    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 71    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 72    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 73    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 74    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 75    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 76    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 77    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 78    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 79    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 80    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 81    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 82    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 83    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 84    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 85    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 86    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 87    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 88    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 89    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 90    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 91    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 92    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 93    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 94    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 95    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 96    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 97    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 98    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
# 99    06  DIRECT PAYMENT FOR SPECIFIED USE, AS A SUBSIDY...  None
#
# [100 rows x 92 columns]

# %%
base_url = "https://api.usaspending.gov"
endpt_trans = "/api/v2/search/spending_by_award/?limit=10"

params = {
    "filters": {
    "time_period": [
        {
            "start_date": "2016-10-01",
            "end_date": "2017-09-30"
        }
    ]
}

}

url = base_url + endpt_trans
r = requests.post(url, json=params)
print(r.status_code, r.reason)
r.raise_for_status()
r.headers
r.request.headers
data = r.json() 
meta = data['page_metadata']
data = data['results']
df_trans = pd.io.json.json_normalize(data)
# Out:
# (422, 'Unprocessable Entity')
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-33-8f1c182eab43> in <module>()
#      17 r = requests.post(url, json=params)
#      18 print(r.status_code, r.reason)
# ---> 19 r.raise_for_status()
#      20 r.headers
#      21 r.request.headers
#
# /Users/mbaumer/anaconda2/lib/python2.7/site-packages/requests/models.pyc in raise_for_status(self)
#     938
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#     942     def close(self):
#
# HTTPError: 422 Client Error: Unprocessable Entity for url: https://api.usaspending.gov/api/v2/search/spending_by_award/?limit=10

# %%
currentFY = 2019
n_years_desired = 10

def download_latest_data(currentFY,n_years_desired):

    #find latest datestamp on usaspending files
    usaspending_base = 'https://files.usaspending.gov/award_data_archive/'
    save_path = '../new_data/'
    r = requests.get(usaspending_base, allow_redirects=True)
    r.raise_for_status()
    datestr = re.findall('_(\d{8}).zip',r.content)[0]

    for FY in np.arange(currentFY-n_years_desired+1,currentFY+1):
        doe_contracts_url = usaspending_base+str(FY)+'_089_Contracts_Full_' + datestr + '.zip'
        doe_grants_url = usaspending_base+str(FY)+'_089_Assistance_Full_' + datestr + '.zip'
        nsf_grants_url = usaspending_base+str(FY)+'_049_Assistance_Full_' + datestr + '.zip'
        doe_sc_url = 'https://science.energy.gov/~/media/_/excel/universities/DOE-SC_Grants_FY'+str(FY)+'.xlsx'

        for url in [doe_contracts_url,doe_grants_url,nsf_grants_url,doe_sc_url]:

            filename = url.split('/')[-1]
            if os.path.exists(save_path+filename): continue

            if url == doe_sc_url: 
                verify='doe_cert.pem'
            else:
                verify=True

            try: 
                r = requests.get(url, allow_redirects=True,verify=verify)
                r.raise_for_status()
            except:
                print 'could not find', url
                continue

            # DOE website stupidly returns a 200 HTTP code when displaying 404 page :/
            page_not_found_text = 'The page that you have requested was not found.'
            if page_not_found_text in r.content: 
                print 'could not find', url
                continue

            open(save_path+filename, 'wb+').write(r.content)
            zipper = zipfile.ZipFile(save_path+filename,'r')
            zipper.extractall(path='../new_data')
    print 'Data download complete'
    
def unzip_all():
    for unzip_this in glob('../new_data/*.zip'):
        zipper = zipfile.ZipFile(unzip_this,'r')
        zipper.extractall(path='../new_data')

# %%
print 'Generating DOE Contract data...'

contract_file_list = glob('../new_data/*089_Contracts*.csv')
contract_df_list = []
for contract_file in contract_file_list:
    contract_df_list.append(pd.read_csv(contract_file))
fulldata = pd.concat(contract_df_list,ignore_index=True)

print len(fulldata)

sc_awarding_offices = ['CHICAGO SERVICE CENTER (OFFICE OF SCIENCE)',
              'OAK RIDGE OFFICE (OFFICE OF SCIENCE)',
              'SC CHICAGO SERVICE CENTER',
              'SC OAK RIDGE OFFICE']

sc_funding_offices = ['CHICAGO SERVICE CENTER (OFFICE OF SCIENCE)',
                      'OAK RIDGE OFFICE (OFFICE OF SCIENCE)',
                      'SCIENCE',
                      'SC OAK RIDGE OFFICE',
                      'SC CHICAGO SERVICE CENTER'
                     ]

sc_contracts = fulldata[(fulldata['awarding_office_name'].isin(
    sc_awarding_offices)) | (fulldata['funding_office_name'].isin(sc_funding_offices))]

print len(sc_contracts)

#sc_contracts.to_pickle('../cleaned_data/sc_contracts.pkl')
# Out:
# Generating DOE Contract data...
# 89160
# 9626

# %%
print 'Generating NSF Grant data...'
grant_file_list = glob('../new_data/*049_Assistance*.csv')
grant_df_list = []
for grant_file in grant_file_list:
    grant_df_list.append(pd.read_csv(grant_file))
fulldata = pd.concat(grant_df_list,ignore_index=True)
len(fulldata)
# Out:
# Generating NSF Grant data...
# /Users/mbaumer/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (21,23,53,59,62,63,64,68,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/mbaumer/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (33,45,65,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/mbaumer/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (21,23,53,59,62,63,64,65,68,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/mbaumer/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (34,48,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/mbaumer/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,2,21,23,33,34,43,45,53,55,59,62,63,64,65,66,68,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 167509

# %%
mps_grants = fulldata[fulldata['cfda_title'] == 'MATHEMATICAL AND PHYSICAL SCIENCES']
len(mps_grants)
# Out:
# 32320

# %%
mps_grants['recipient_congressional_district'].unique()
# Out:
# array([ 0.,  1., nan,  7.,  5.,  9., 25., 34., 32., 13., 23.,  3., 14.,
#        12., 24.,  2., 17., 10., 45.,  8., 16.,  4., 27., 11., 21., 49.,
#         6., 31., 18., 15., 20., 22., 33., 26., 19., 30., 47., 39., 37.,
#        44., 28., 35., 50., 52., 48., 53., 46., 29., 98., 41., 36., 90.,
#        43., 40., 38.])

# %%
    mps_grants = mps_grants.dropna(subset=['principal_place_cd'])

    strlist = []
    for code in mps_grants['principal_place_cd'].values:
        if code == 'ZZ':
            code = '00'
        if len(str(int(code))) < 2:
            strlist.append('0' + str(int(code)))
        else:
            strlist.append(str(int(code)))

    mps_grants['cong_dist'] = mps_grants['principal_place_state_code'] + strlist
    pd.to_pickle(mps_grants, '../cleaned_data/nsf_mps_grants.pkl')
